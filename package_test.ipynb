# %%
import flapper
from flapper import InitialCondition, Trainer

# %%
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
trainer = Trainer()

# train from scratch
icfn = lambda: InitialCondition().random(['f2','distance', 'A2'])
history  = trainer.train(initial_condition_fn=icfn, episodes=5000)
# Out:
# Episode 20 	 avg length: 204 	 reward: -103.15809962659307
# Episode 40 	 avg length: 119 	 reward: -96.21986916015219
# Episode 60 	 avg length: 162 	 reward: -102.73926104967268
# Episode 80 	 avg length: 144 	 reward: -101.45743503899273
# Episode 100 	 avg length: 131 	 reward: -96.75145041290469
# Episode 120 	 avg length: 218 	 reward: -92.47992306026515
# Episode 140 	 avg length: 207 	 reward: -87.10867893792224
# Episode 160 	 avg length: 203 	 reward: -92.57380616932984
# Episode 180 	 avg length: 221 	 reward: -86.88319468016451
# Episode 200 	 avg length: 139 	 reward: -86.28898273051212
# Episode 220 	 avg length: 185 	 reward: -96.65785987486564
# Episode 240 	 avg length: 197 	 reward: -103.70500457293079
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       4 # train from scratch
#       5 icfn = lambda: InitialCondition().random(['f2','distance', 'A2'])
# ----> 6 history  = trainer.train(initial_condition_fn=icfn, episodes=5000)
#
# File ~/Downloads/flapper/model.py:211, in Trainer.train(self, initial_condition, initial_condition_fn, episodes)
#     209 # update if its time
#     210 if timestep % self.update_timestep == 0:
# --> 211     self.ppo.update(self.memory)
#     212     self.memory.clear_memory()
#     213     timestep = 0
#
# File ~/Downloads/flapper/model.py:139, in PPO.update(self, memory)
#     137     self.optimizer.zero_grad()
#     138     loss.mean().backward()
# --> 139     self.optimizer.step()
#     141 # Copy new weights into old policy:
#     142 self.policy_old.load_state_dict(self.policy.state_dict())
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/optim/optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/optim/optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/optim/adam.py:244, in Adam.step(self, closure)
#     232     beta1, beta2 = group["betas"]
#     234     has_complex = self._init_group(
#     235         group,
#     236         params_with_grad,
#    (...)    241         state_steps,
#     242     )
# --> 244     adam(
#     245         params_with_grad,
#     246         grads,
#     247         exp_avgs,
#     248         exp_avg_sqs,
#     249         max_exp_avg_sqs,
#     250         state_steps,
#     251         amsgrad=group["amsgrad"],
#     252         has_complex=has_complex,
#     253         beta1=beta1,
#     254         beta2=beta2,
#     255         lr=group["lr"],
#     256         weight_decay=group["weight_decay"],
#     257         eps=group["eps"],
#     258         maximize=group["maximize"],
#     259         foreach=group["foreach"],
#     260         capturable=group["capturable"],
#     261         differentiable=group["differentiable"],
#     262         fused=group["fused"],
#     263         grad_scale=getattr(self, "grad_scale", None),
#     264         found_inf=getattr(self, "found_inf", None),
#     265     )
#     267 return loss
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/optim/optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/optim/adam.py:876, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     873 else:
#     874     func = _single_tensor_adam
# --> 876 func(
#     877     params,
#     878     grads,
#     879     exp_avgs,
#     880     exp_avg_sqs,
#     881     max_exp_avg_sqs,
#     882     state_steps,
#     883     amsgrad=amsgrad,
#     884     has_complex=has_complex,
#     885     beta1=beta1,
#     886     beta2=beta2,
#     887     lr=lr,
#     888     weight_decay=weight_decay,
#     889     eps=eps,
#     890     maximize=maximize,
#     891     capturable=capturable,
#     892     differentiable=differentiable,
#     893     grad_scale=grad_scale,
#     894     found_inf=found_inf,
#     895 )
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/optim/adam.py:478, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     475     else:
#     476         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 478     param.addcdiv_(exp_avg, denom, value=-step_size)
#     480 # Lastly, switch back to complex view
#     481 if amsgrad and torch.is_complex(params[i]):
#
# KeyboardInterrupt:

# %%
trainer.test_policy(InitialCondition(distance=dd, f2=2.) for dd in range(20, 65, 10))
